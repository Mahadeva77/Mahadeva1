# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahadeva77/Mahadeva1/blob/main/part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = { "Name": ["Asha", "Ravi", "Meera", "Karan"], "Marks": [88, 72, 91, 65], "Branch": ["CSE", "ECE", "CSE", "ISE"] }

# %%
df = pd.DataFrame(data)
print("\n--- Pandas DataFrame ---")
print(df)
# Out:
# --- Pandas DataFrame ---
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISE

# %%
print("\n--- Column Indexing ---")
print("Name Column:")
print(df["Name"])
print("\nMarks Column:")
print(df["Marks"])
# Out:
# --- Column Indexing ---
# Name Column:
# 0     Asha
# 1     Ravi
# 2    Meera
# 3    Karan
# Name: Name, dtype: object
#
# Marks Column:
# 0    88
# 1    72
# 2    91
# 3    65
# Name: Marks, dtype: int64

# %%
print("\n--- Row Indexing ---")
print("First Row:")
print(df.iloc[0])
print("\nThird Row:")
print(df.iloc[2])
# Out:
# --- Row Indexing ---
# First Row:
# Name      Asha
# Marks       88
# Branch     CSE
# Name: 0, dtype: object
#
# Third Row:
# Name      Meera
# Marks        91
# Branch      CSE
# Name: 2, dtype: object

# %%
print("\n--- Specific Value ---")
print("Marks of first student:", df.iloc[0, 1])
# Out:
# --- Specific Value ---
# Marks of first student: 88

# %%
print("\n--- Row Slicing ---")
print("First two rows:")
print(df.iloc[0:2])
# Out:
# --- Row Slicing ---
# First two rows:
#    Name  Marks Branch
# 0  Asha     88    CSE
# 1  Ravi     72    ECE

# %%
print("\n--- Row and Column Slicing ---")
print("First three rows with Name and Marks:")
print(df.iloc[0:3, [0, 1]])
# Out:
# --- Row and Column Slicing ---
# First three rows with Name and Marks:
#     Name  Marks
# 0   Asha     88
# 1   Ravi     72
# 2  Meera     91

# %%
print("\n--- Data Filtering ---")
result = df[df["Marks"] > 70]
print("Students with Marks greater than 70:")
print(result)
# Out:
# --- Data Filtering ---
# Students with Marks greater than 70:
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
